# %%
import pandas as pd
import glob

# %%
df = pd.concat(map(pd.read_csv, glob.glob("../csv/" + "/*.csv")), ignore_index=True)
df.shape
# Out:
# (2049, 44)

# %%
df
# Out:
#                                        filename        1x        1y        2x  \
# 0     ../raw_data/scissors/dFlxUAypUgfOZqoV.png  0.972548  0.503541  0.888238
# 1     ../raw_data/scissors/b4Qm4ZK5AAUQo1Ax.png  0.883314  0.585556  0.758897
# 2     ../raw_data/scissors/msOEQAWveiL7r5rp.png  0.910765  0.598994  0.836391
# 3     ../raw_data/scissors/FfCLY0qhfyOoyam8.png  0.942804  0.452263  0.843116
# 4     ../raw_data/scissors/7jLYhf025vHEX7kp.png  0.916129  0.525466  0.825934
# ...                                         ...       ...       ...       ...
# 2044      ../raw_data/rock/aEjSJwrTtf651GLm.png  0.801997  0.391905  0.755212
# 2045      ../raw_data/rock/N235Vnlue0M9SwaK.png  0.784961  0.542601  0.693826
# 2046      ../raw_data/rock/jJVH6kP3VRPHbWvs.png  0.756038  0.627848  0.645485
# 2047      ../raw_data/rock/Yux1PtSfRvXafFLT.png  0.979933  0.361096  0.910629
# 2048      ../raw_data/rock/UJ1D4UeUI0pnDG5h.png  0.612991  0.407836  0.516915
#
#             2y        3x        3y        4x        4y        5x  ...  \
# 0     0.670902  0.766331  0.698617  0.688033  0.595593  0.653848  ...
# 1     0.738274  0.619175  0.731899  0.540562  0.609661  0.514005  ...
# 2     0.407034  0.722001  0.359720  0.642534  0.440818  0.602230  ...
# 3     0.593405  0.718336  0.579437  0.654337  0.451111  0.632054  ...
# 4     0.410975  0.722051  0.406688  0.660051  0.489497  0.622740  ...
# ...        ...       ...       ...       ...       ...       ...  ...
# 2044  0.581663  0.637933  0.679944  0.513484  0.711181  0.422677  ...
# 2045  0.751510  0.569009  0.851166  0.437786  0.872036  0.356097  ...
# 2046  0.434717  0.524790  0.371149  0.425637  0.415381  0.388502  ...
# 2047  0.586505  0.797917  0.702587  0.667653  0.747208  0.572597  ...
# 2048  0.645689  0.408314  0.747573  0.317932  0.711735  0.280177  ...
#
#            17y       18x       18y       19x       19y       20x       20y  \
# 0     0.439262  0.785297  0.249039  0.682782  0.291712  0.707206  0.337388
# 1     0.516720  0.639559  0.312580  0.554995  0.351059  0.577250  0.405897
# 2     0.562702  0.660576  0.772937  0.619692  0.700938  0.657051  0.666762
# 3     0.299582  0.769897  0.152735  0.655527  0.150431  0.675466  0.203113
# 4     0.635309  0.720663  0.833326  0.715275  0.790811  0.755227  0.748631
# ...        ...       ...       ...       ...       ...       ...       ...
# 2044  0.388263  0.562001  0.253626  0.436179  0.272504  0.473747  0.291095
# 2045  0.504730  0.514077  0.350884  0.465629  0.387204  0.499006  0.399546
# 2046  0.663950  0.507356  0.831950  0.444836  0.765239  0.472063  0.743014
# 2047  0.411233  0.734088  0.194165  0.621057  0.281826  0.653770  0.321119
# 2048  0.417108  0.269538  0.276247  0.276238  0.311557  0.321564  0.320868
#
#            21x       21y  target
# 0     0.752084  0.343444       2
# 1     0.619907  0.421913       2
# 2     0.697424  0.658073       2
# 3     0.716827  0.225120       2
# 4     0.783695  0.725269       2
# ...        ...       ...     ...
# 2044  0.522528  0.292327       0
# 2045  0.533204  0.397571       0
# 2046  0.506388  0.752688       0
# 2047  0.696890  0.298820       0
# 2048  0.364439  0.322860       0
#
# [2049 rows x 44 columns]

# %%
df.to_csv('../csv/chifoumi-dataset.csv', index=False)

# %% [markdown]
# ===============================================

# %%
from IPython.display import display, Image
display(Image(filename='MyImage.png'))

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread('MyImage.png'))

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
img = mpimg.imread('your_image.png')
imgplot = plt.imshow(img)
plt.show()

# %%
from PIL import Image

image = Image.open('image.jpg')
image.show()
