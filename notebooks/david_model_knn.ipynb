# %%
import pandas as pd

# %%
df = pd.read_csv('chifoumy/data/chifoumi-dataset.csv')
df.head()
# Out:
#                                     filename        1x        1y        1z  \
# 0  ../raw_data/scissors/dFlxUAypUgfOZqoV.png  0.972548  0.503541  0.000002
# 1  ../raw_data/scissors/b4Qm4ZK5AAUQo1Ax.png  0.883314  0.585556  0.000001
# 2  ../raw_data/scissors/msOEQAWveiL7r5rp.png  0.910765  0.598994  0.000001
# 3  ../raw_data/scissors/FfCLY0qhfyOoyam8.png  0.942804  0.452263  0.000001
# 4  ../raw_data/scissors/7jLYhf025vHEX7kp.png  0.916129  0.525466  0.000002
#
#          2x        2y        2z        3x        3y        3z  ...       19x  \
# 0  0.888238  0.670902 -0.020812  0.766331  0.698617 -0.052920  ...  0.682782
# 1  0.758897  0.738274 -0.000408  0.619175  0.731899 -0.014292  ...  0.554995
# 2  0.836391  0.407034 -0.027133  0.722001  0.359720 -0.052438  ...  0.619692
# 3  0.843116  0.593405 -0.018791  0.718336  0.579437 -0.043036  ...  0.655527
# 4  0.825934  0.410975 -0.030042  0.722051  0.406688 -0.057272  ...  0.715275
#
#         19y       19z       20x       20y       20z       21x       21y  \
# 0  0.291712 -0.138871  0.707206  0.337388 -0.104174  0.752084  0.343444
# 1  0.351059 -0.067778  0.577250  0.405897 -0.036943  0.619907  0.421913
# 2  0.700938 -0.096034  0.657051  0.666762 -0.070877  0.697424  0.658073
# 3  0.150431 -0.129719  0.675466  0.203113 -0.098801  0.716827  0.225120
# 4  0.790811 -0.111477  0.755227  0.748631 -0.089387  0.783695  0.725269
#
#         21z  target
# 0 -0.066942       2
# 1 -0.008412       2
# 2 -0.042735       2
# 3 -0.063351       2
# 4 -0.060035       2
#
# [5 rows x 65 columns]

# %%
df.shape
# Out:
# (8208, 65)

# %%
df.describe()
# Out:
#                 1x           1y            1z           2x           2y  \
# count  8208.000000  8208.000000  8.208000e+03  8208.000000  8208.000000
# mean      0.498215     0.496042  5.731623e-07     0.497596     0.553043
# std       0.292279     0.292288  1.221204e-06     0.257598     0.250718
# min      -0.150064    -0.147117 -3.062199e-06    -0.078356    -0.070512
# 25%       0.263999     0.270309 -3.524245e-07     0.266912     0.326108
# 50%       0.497810     0.489946  9.255353e-07     0.495409     0.627914
# 75%       0.731976     0.736126  1.478217e-06     0.728109     0.748820
# max       1.149934     1.110032  3.154388e-06     1.072792     1.069952
#
#                 2z           3x           3y           3z           4x  ...  \
# count  8208.000000  8208.000000  8208.000000  8208.000000  8208.000000  ...
# mean     -0.015087     0.497673     0.571352    -0.029864     0.497956  ...
# std       0.031433     0.223186     0.210190     0.048612     0.189036  ...
# min      -0.263005    -0.040289    -0.000656    -0.317181    -0.046079  ...
# 25%      -0.035257     0.301580     0.371687    -0.059719     0.372164  ...
# 50%      -0.016675     0.495612     0.632259    -0.034268     0.497721  ...
# 75%       0.005558     0.694955     0.735060     0.002794     0.625498  ...
# max       0.186926     1.030578     1.023172     0.273608     1.030922  ...
#
#                19x          19y          19z          20x          20y  \
# count  8208.000000  8208.000000  8208.000000  8208.000000  8208.000000
# mean      0.498494     0.440604    -0.072921     0.497850     0.448023
# std       0.186719     0.177661     0.079548     0.179455     0.172675
# min      -0.085957    -0.065340    -0.374900    -0.151302    -0.058732
# 25%       0.353425     0.301338    -0.125974     0.355797     0.317883
# 50%       0.499253     0.430815    -0.084451     0.498642     0.420642
# 75%       0.644160     0.553720    -0.012203     0.639919     0.573186
# max       1.076971     1.078582     0.361737     1.141539     1.140382
#
#                20z          21x          21y          21z       target
# count  8208.000000  8208.000000  8208.000000  8208.000000  8208.000000
# mean     -0.055157     0.497903     0.450076    -0.038176     1.001706
# std       0.089577     0.191972     0.185598     0.095996     0.812356
# min      -0.409124    -0.205810    -0.076648    -0.429250     0.000000
# 25%      -0.115241     0.336347     0.309523    -0.105654     0.000000
# 50%      -0.069765     0.497461     0.401043    -0.040849     1.000000
# 75%       0.014488     0.659332     0.610617     0.033325     2.000000
# max       0.437521     1.196496     1.192943     0.491018     2.000000
#
# [8 rows x 64 columns]

# %%
data = df.copy()

# %%
X = data.drop(['target','filename'], axis = 1)
y = data['target']

# %%
X.shape
X_normalized = X.copy()
X_normalized.info()
X_normalized.shape[1]
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8208 entries, 0 to 8207
# Data columns (total 63 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   1x      8208 non-null   float64
#  1   1y      8208 non-null   float64
#  2   1z      8208 non-null   float64
#  3   2x      8208 non-null   float64
#  4   2y      8208 non-null   float64
#  5   2z      8208 non-null   float64
#  6   3x      8208 non-null   float64
#  7   3y      8208 non-null   float64
#  8   3z      8208 non-null   float64
#  9   4x      8208 non-null   float64
#  10  4y      8208 non-null   float64
#  11  4z      8208 non-null   float64
#  12  5x      8208 non-null   float64
#  13  5y      8208 non-null   float64
#  14  5z      8208 non-null   float64
#  15  6x      8208 non-null   float64
#  16  6y      8208 non-null   float64
#  17  6z      8208 non-null   float64
#  18  7x      8208 non-null   float64
#  19  7y      8208 non-null   float64
#  20  7z      8208 non-null   float64
#  21  8x      8208 non-null   float64
#  22  8y      8208 non-null   float64
#  23  8z      8208 non-null   float64
#  24  9x      8208 non-null   float64
#  25  9y      8208 non-null   float64
#  26  9z      8208 non-null   float64
#  27  10x     8208 non-null   float64
#  28  10y     8208 non-null   float64
#  29  10z     8208 non-null   float64
#  30  11x     8208 non-null   float64
#  31  11y     8208 non-null   float64
#  32  11z     8208 non-null   float64
#  33  12x     8208 non-null   float64
#  34  12y     8208 non-null   float64
#  35  12z     8208 non-null   float64
#  36  13x     8208 non-null   float64
#  37  13y     8208 non-null   float64
#  38  13z     8208 non-null   float64
#  39  14x     8208 non-null   float64
#  40  14y     8208 non-null   float64
#  41  14z     8208 non-null   float64
#  42  15x     8208 non-null   float64
#  43  15y     8208 non-null   float64
#  44  15z     8208 non-null   float64
#  45  16x     8208 non-null   float64
#  46  16y     8208 non-null   float64
#  47  16z     8208 non-null   float64
#  48  17x     8208 non-null   float64
#  49  17y     8208 non-null   float64
#  50  17z     8208 non-null   float64
#  51  18x     8208 non-null   float64
#  52  18y     8208 non-null   float64
#  53  18z     8208 non-null   float64
#  54  19x     8208 non-null   float64
#  55  19y     8208 non-null   float64
#  56  19z     8208 non-null   float64
#  57  20x     8208 non-null   float64
#  58  20y     8208 non-null   float64
#  59  20z     8208 non-null   float64
#  60  21x     8208 non-null   float64
#  61  21y     8208 non-null   float64
#  62  21z     8208 non-null   float64
# dtypes: float64(63)
# memory usage: 3.9 MB
# 63

# %%
X_normalized["13x"] - X_normalized["1x"]
# Out:
# 0      -0.684897
# 1      -0.713968
# 2      -0.690299
# 3      -0.676331
# 4      -0.647108
#           ...
# 8203   -0.103276
# 8204   -0.078853
# 8205    0.064557
# 8206   -0.163813
# 8207   -0.130269
# Length: 8208, dtype: float64

# %%
X_normalized.apply(lambda x : x/(X_normalized["13x"] - X_normalized["1x"]))
# Out:
#             1x         1y        1z        2x        2y        2z        3x  \
# 0    -1.419992  -0.735207 -0.000002 -1.296893 -0.979567  0.030387 -1.118900
# 1    -1.237191  -0.820143 -0.000002 -1.062929 -1.034044  0.000572 -0.867231
# 2    -1.319378  -0.867731 -0.000002 -1.211637 -0.589650  0.039306 -1.045925
# 3    -1.393998  -0.668700 -0.000002 -1.246603 -0.877389  0.027784 -1.062107
# 4    -1.415730  -0.812022 -0.000002 -1.276347 -0.635095  0.046426 -1.115812
# ...        ...        ...       ...       ...       ...       ...       ...
# 8203 -5.770433  -7.649717  0.000009 -4.003454 -7.220132  0.214540 -3.113353
# 8204 -5.809413  -9.983725  0.000017 -3.109187 -8.806491 -0.204347 -1.787483
# 8205  5.819297  11.769917 -0.000009  8.744074  9.909586  0.285411  9.657638
# 8206 -3.867392  -5.974123  0.000009 -2.508374 -5.548627  0.075207 -1.792387
# 8207 -4.511618  -4.722940  0.000014 -2.671344 -3.977994 -0.235670 -1.866174
#
#             3y        3z        4x  ...       18z       19x       19y  \
# 0    -1.020032  0.077266 -1.004579  ...  0.178082 -0.996912 -0.425921
# 1    -1.025115  0.020017 -0.757124  ...  0.106310 -0.777339 -0.491702
# 2    -0.521108  0.075964 -0.930806  ...  0.126946 -0.897716 -1.015413
# 3    -0.856736  0.063632 -0.967480  ...  0.159956 -0.969240 -0.222422
# 4    -0.628471  0.088505 -1.020002  ...  0.146733 -1.105342 -1.222071
# ...        ...       ...       ...  ...       ...       ...       ...
# 8203 -6.103563  0.438851 -2.856624  ...  1.177138 -7.028845 -4.236773
# 8204 -7.248637 -0.196463 -1.511597  ...  0.062412 -7.721037 -5.948422
# 8205  8.000838  0.265996  8.997381  ... -0.898841  3.518728  6.830824
# 8206 -4.868400  0.228951 -1.483434  ...  0.513537 -4.352797 -3.783805
# 8207 -3.130806 -0.224369 -2.140497  ...  0.268573 -5.200559 -2.120601
#
#            19z       20x       20y       20z       21x       21y       21z
# 0     0.202762 -1.032573 -0.492612  0.152101 -1.098098 -0.501453  0.097740
# 1     0.094931 -0.808510 -0.568509  0.051744 -0.868256 -0.590941  0.011783
# 2     0.139119 -0.951835 -0.965904  0.102675 -1.010322 -0.953316  0.061908
# 3     0.191798 -0.998721 -0.300315  0.146083 -1.059876 -0.332854  0.093668
# 4     0.172270 -1.167081 -1.156888  0.138133 -1.211073 -1.120786  0.092774
# ...        ...       ...       ...       ...       ...       ...       ...
# 8203  1.208414 -6.812956 -4.584702  0.773196 -6.776698 -5.045735  0.414334
# 8204 -0.463215 -7.530145 -6.354261 -1.012997 -7.564965 -6.801526 -1.324920
# 8205 -0.310264  3.918988  7.234386  0.263206  3.810626  7.790337  0.572912
# 8206  0.453575 -4.107063 -3.982913  0.158528 -4.252658 -4.235827 -0.057212
# 8207 -0.007891 -5.118541 -2.470764 -0.265717 -5.120399 -2.802261 -0.437519
#
# [8208 rows x 63 columns]

# %%
X_normalized.describe()
# Out:
#                 1x           1y            1z           2x           2y  \
# count  8208.000000  8208.000000  8.208000e+03  8208.000000  8208.000000
# mean      0.498215     0.496042  5.731623e-07     0.497596     0.553043
# std       0.292279     0.292288  1.221204e-06     0.257598     0.250718
# min      -0.150064    -0.147117 -3.062199e-06    -0.078356    -0.070512
# 25%       0.263999     0.270309 -3.524245e-07     0.266912     0.326108
# 50%       0.497810     0.489946  9.255353e-07     0.495409     0.627914
# 75%       0.731976     0.736126  1.478217e-06     0.728109     0.748820
# max       1.149934     1.110032  3.154388e-06     1.072792     1.069952
#
#                 2z           3x           3y           3z           4x  ...  \
# count  8208.000000  8208.000000  8208.000000  8208.000000  8208.000000  ...
# mean     -0.015087     0.497673     0.571352    -0.029864     0.497956  ...
# std       0.031433     0.223186     0.210190     0.048612     0.189036  ...
# min      -0.263005    -0.040289    -0.000656    -0.317181    -0.046079  ...
# 25%      -0.035257     0.301580     0.371687    -0.059719     0.372164  ...
# 50%      -0.016675     0.495612     0.632259    -0.034268     0.497721  ...
# 75%       0.005558     0.694955     0.735060     0.002794     0.625498  ...
# max       0.186926     1.030578     1.023172     0.273608     1.030922  ...
#
#                18z          19x          19y          19z          20x  \
# count  8208.000000  8208.000000  8208.000000  8208.000000  8208.000000
# mean     -0.068996     0.498494     0.440604    -0.072921     0.497850
# std       0.057188     0.186719     0.177661     0.079548     0.179455
# min      -0.311993    -0.085957    -0.065340    -0.374900    -0.151302
# 25%      -0.105156     0.353425     0.301338    -0.125974     0.355797
# 50%      -0.070328     0.499253     0.430815    -0.084451     0.498642
# 75%      -0.029522     0.644160     0.553720    -0.012203     0.639919
# max       0.240199     1.076971     1.078582     0.361737     1.141539
#
#                20y          20z          21x          21y          21z
# count  8208.000000  8208.000000  8208.000000  8208.000000  8208.000000
# mean      0.448023    -0.055157     0.497903     0.450076    -0.038176
# std       0.172675     0.089577     0.191972     0.185598     0.095996
# min      -0.058732    -0.409124    -0.205810    -0.076648    -0.429250
# 25%       0.317883    -0.115241     0.336347     0.309523    -0.105654
# 50%       0.420642    -0.069765     0.497461     0.401043    -0.040849
# 75%       0.573186     0.014488     0.659332     0.610617     0.033325
# max       1.140382     0.437521     1.196496     1.192943     0.491018
#
# [8 rows x 63 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
X_scaled = MinMaxScaler().fit_transform(X)

# %%
baseline_score = 1/3
baseline_score
# Out:
# 0.3333333333333333

# %%
from sklearn.model_selection import train_test_split, cross_validate
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.3)

# %%
from sklearn.dummy import DummyClassifier
model_dummy = DummyClassifier()

# %%
base_scores = cross_validate(model_dummy, X_train, y_train, cv = 5, scoring = 'accuracy')

# %%
base_scores['test_score'].mean()
# Out:
# 0.34134029590948656

# %%
from sklearn.neighbors import KNeighborsClassifier
model_knn = KNeighborsClassifier()

# %%
base_knn = cross_validate(model_knn,X_train, y_train, cv = 5, scoring = 'accuracy')
base_knn
# Out:
# {'fit_time': array([0.00147414, 0.00082612, 0.00073195, 0.00084877, 0.00078106]),
#  'score_time': array([0.05639482, 0.02229905, 0.02001882, 0.02196193, 0.0268929 ]),
#  'test_score': array([0.99912968, 0.99477807, 0.99738903, 0.99651871, 0.99564839])}

# %%
base_knn['test_score'].mean()
# Out:
# 0.9966927763272411

# %%
# %%time
from sklearn.model_selection import RandomizedSearchCV
from scipy import stats

# Instanciate model
model = model_knn

# Hyperparameter search space
search_space = {
    'n_neighbors': [1, 2, 3, 4, 5],
    'p': [1, 2]
}

# Instanciate Random Search
rsearch = RandomizedSearchCV(
    model, search_space,
    n_jobs=-1, scoring='accuracy', cv=5, n_iter=10, verbose=0)


rsearch.fit(X_scaled,y)
# Out:
# CPU times: user 95.7 ms, sys: 97.4 ms, total: 193 ms
# Wall time: 5.23 s
# RandomizedSearchCV(cv=5, estimator=KNeighborsClassifier(), n_jobs=-1,
#                    param_distributions={'n_neighbors': [1, 2, 3, 4, 5],
#                                         'p': [1, 2]},
#                    scoring='accuracy')

# %%
rsearch.best_params_
# Out:
# {'p': 2, 'n_neighbors': 3}

# %%
import numpy as np
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
# create the training size slices
train_sizes = np.linspace(1, 6566, num = 100, dtype='int')

# Get train scores, train sizes, and validation scores using `learning_curve`, r2 score
train_sizes, train_scores, test_scores = learning_curve(estimator = KNeighborsClassifier(n_neighbors = 3, p=2),
                                                              X = X_scaled, 
                                                              y = y,
                                                        scoring = 'accuracy',
                                                             train_sizes = train_sizes, 
                                                              cv = 5)

# Take the mean of cross-validated train scores and validation scores
train_scores_mean = np.mean(train_scores, axis=1)
test_scores_mean = np.mean(test_scores, axis=1)

# Plot the learning curves!
plt.figure(figsize=(10,6))
plt.plot(train_sizes, train_scores_mean, label = 'training score')
plt.plot(train_sizes, test_scores_mean, label = 'test score')
plt.ylabel('accuracy', fontsize = 14)
plt.xlabel('Training set size', fontsize = 14)
plt.title('Learning curves', fontsize = 18, y = 1.03)
plt.legend();
# Out:
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(
# /Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py:776: UserWarning: Scoring failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/model_selection/_validation.py", line 767, in _score
#     scores = scorer(estimator, X_test, y_test)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 219, in __call__
#     return self._score(
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 261, in _score
#     y_pred = method_caller(estimator, "predict", X)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/metrics/_scorer.py", line 71, in _cached_call
#     return getattr(estimator, method)(*args, **kwargs)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_classification.py", line 226, in predict
#     neigh_ind = self.kneighbors(X, return_distance=False)
#   File "/Users/davidr/.pyenv/versions/chifoumy/lib/python3.10/site-packages/sklearn/neighbors/_base.py", line 749, in kneighbors
#     raise ValueError(
# ValueError: Expected n_neighbors <= n_samples,  but n_samples = 1, n_neighbors = 3
#
#   warnings.warn(

# %%
# %%time
model_knn = KNeighborsClassifier(n_neighbors = 1, p=2)
model_knn.fit(X_train, y_train)
y_pred = model_knn.predict(X_test)
# Out:
# CPU times: user 315 ms, sys: 78.5 ms, total: 393 ms
# Wall time: 57.6 ms

# %%
results_df = pd.DataFrame({"actual": y_test,
                           "predicted": y_pred}) #Store results in a dataframe

confusion_matrix = pd.crosstab(index= results_df['actual'],
                               columns = results_df['predicted'])
confusion_matrix
# Out:
# predicted    0    1    2
# actual
# 0          816    0    0
# 1            0  830    1
# 2            1    2  813

# %%
X_test.shape, y_test.shape
# Out:
# ((2463, 63), (2463,))

# %%
score = cross_validate(model_knn, X_train, y_train, scoring='accuracy')

# %%
score
# Out:
# {'fit_time': array([0.00079179, 0.00065303, 0.00063896, 0.00074506, 0.00071478]),
#  'score_time': array([0.0220499 , 0.01980495, 0.01885796, 0.01819277, 0.02078414]),
#  'test_score': array([0.99825936, 0.99651871, 0.99912968, 0.99825936, 0.99825936])}

# %%
score['test_score'].mean()
# Out:
# 0.9980852915578764
